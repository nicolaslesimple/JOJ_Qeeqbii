# %%
import pandas as pd
import numpy as np
import sys

# %% [markdown]
# ### Reading of the train set

# %%
column_names = ['id','name','barcode','category','Énergie (kJ)','Sel (g)','Protéines (g)','Sucres (g)',\
                'Glucides (g)','Matières grasses (g)','Acides gras saturés (g)','Fibres alimentaires (g)',\
                'Biotine (µg)','Vitamine B1 (Thiamine) (mg)','Vitamine E (Tocopherol) (mg)','Acide folique (µg)',\
                'Vitamine A (µg)','Vitamine D (Cholacalciferol) (µg)','Vitamine C (Acide ascorbique) (mg)',\
                'Vitamine B6 (Pyridoxine) (mg)','Vitamine B5 (acide pantothénique) (mg)','Vitamine B3 (Niacine) (mg)',\
                'Vitamine B2 (Riboflavine) (mg)','Vitamine B12 (Cobalamine) (µg)','endline', 'extra']
train_set = pd.read_csv('../cluster_train_set.csv', names = column_names)

# %% [markdown]
# ### Dropping unfound products in OpenFood

# %%
# dropping first line that repeats columns
train_set.drop(0, inplace=True)
train_set = train_set[train_set['name'].notnull()]

# %% [markdown]
# ### Processing of product names containing ','
#
# For the elements of the train set that had a ',' in their name the csv formatting shifted every value and created an extra column. Every value is reassigned to its right place below.

# %%
elem_to_shift = train_set[train_set['extra'].notnull()].copy()
for i in range(elem_to_shift.shape[0]):
    line = elem_to_shift.iloc[i].copy()
    line_values = line.values
    line_values[1] = line_values[1] + line_values[2]
    line_values = np.delete(line_values, 2)
    line_values = np.append(line_values, [np.nan])
    elem_to_shift.iloc[i] = line_values

train_set[train_set['extra'].notnull()] = elem_to_shift

# %% [markdown]
# ### Processing categories that have more than 2 levels by removing extra levels

# %%
catagory_column_value = train_set['category'].values

for i in range(train_set.shape[0]):
    if catagory_column_value[i].count('/') > 2:
        current_category =  catagory_column_value[i]
        slash_indexes = [pos for pos, char in enumerate(current_category) if char == '/']
        catagory_column_value[i] = current_category[:slash_indexes[2]]

train_set['category'] = catagory_column_value

# %% [markdown]
# ### Dropping useless columns

# %%
train_set.drop(['extra', 'endline'], axis = 1, inplace = True)

# %%
train_set.columns
# Out:
# Index(['id', 'name', 'barcode', 'category', 'Énergie (kJ)', 'Sel (g)',
#        'Protéines (g)', 'Sucres (g)', 'Glucides (g)', 'Matières grasses (g)',
#        'Acides gras saturés (g)', 'Fibres alimentaires (g)', 'Biotine (µg)',
#        'Vitamine B1 (Thiamine) (mg)', 'Vitamine E (Tocopherol) (mg)',
#        'Acide folique (µg)', 'Vitamine A (µg)',
#        'Vitamine D (Cholacalciferol) (µg)',
#        'Vitamine C (Acide ascorbique) (mg)', 'Vitamine B6 (Pyridoxine) (mg)',
#        'Vitamine B5 (acide pantothénique) (mg)', 'Vitamine B3 (Niacine) (mg)',
#        'Vitamine B2 (Riboflavine) (mg)', 'Vitamine B12 (Cobalamine) (µg)'],
#       dtype='object')

# %% [markdown]
# ### Dropping products that didn't have a nutrient list

# %%
train_set_values = train_set[train_set.columns[4:]].values.astype(float)
train_set = train_set[np.abs(np.sum(train_set_values, axis =1)) > 1e-3]

# %%
train_set.shape
# Out:
# (4654, 24)

# %% [markdown]
# ### Renaming categories with only one level in "To classify"

# %%
catagory_column_value = train_set['category'].values

for i in range(train_set.shape[0]):
    if catagory_column_value[i].count('/') < 2:
        catagory_column_value[i] = "To classify"

train_set['category'] = catagory_column_value

# %% [markdown]
# ### Saving preprocessed train set before computing clusters

# %%
train_set.shape
# Out:
# (4654, 21)

# %%
path = '../preprocessed_cluster_train_set.csv'
train_set.to_csv(path, index = False)

# %% [markdown]
# ### Rereading of the train_set

# %%
train_set = pd.read_csv(path)

# %% [markdown]
# ### Dropping columns not useful for clustering

# %%
train_set.drop(['id', 'name', 'barcode'], axis = 1, inplace = True)

# %% [markdown]
# ### Computing cluster centers

# %%
unique_categories = train_set['category'].unique()
cluster_centers = np.zeros((unique_categories.shape[0], train_set.shape[1]-1))

# We compute the nutrient center of gravity of each of the 250 categories
for index, category in enumerate(unique_categories):
    category_train_set = train_set[train_set['category'] == category]
    category_train_set_values = category_train_set.values[:,1:].astype(float)
    nutrient_stack = np.zeros(train_set.shape[1]-1)
    
    for i in range(category_train_set_values.shape[0]):
        
        nutrient_array = category_train_set_values[i,:]
        nutrient_stack = nutrient_stack + nutrient_array
    
    
    cluster_centers[index] = nutrient_stack / category_train_set_values.shape[0]

unique_categories = np.expand_dims(unique_categories, axis = 1)
categories_center_values = np.concatenate([unique_categories, cluster_centers], axis = 1)
    
categories_center_df = pd.DataFrame(categories_center_values, columns = column_names[3:-2])

# %%
categories_center_df
# Out:
#                                               category Énergie (kJ)  \
# 0                        /chocolat/bonbons-chewing-gum      1168.26
# 1            /petit-dejeuner/cacao-chocolats-en-poudre      1480.65
# 2      /boissons-chaudes-froides/boissons-energetiques      280.759
# 3                                   /chocolat/chocolat      2250.61
# 4                                   /chocolat/sain-bio      1936.35
# 5          /garnitures-ingredients/tomates-en-conserve      253.429
# 6              /garnitures-ingredients/du-monde-entier      977.976
# 7                           /chocolat/biscuits-gaufres      2066.71
# 8       /garnitures-ingredients/soupes-sauces-bouillon      636.444
# 9                    /produits-surgeles/plats-cuisines      642.679
# 10                  /plats-cuisines/pizza-menus-snacks      680.106
# 11                  /produits-surgeles/glace-entremets      886.354
# 12                /mueesli-cereales/barres-de-cereales      1670.03
# 13            /boulangerie/biscottes-pain-croustillant      1763.28
# 14                   /produits-laitiers-oeufs/fromages      1168.19
# 15                                         To classify      1304.76
# 16                          /mueesli-cereales/cereales      1704.92
# 17                                 /boulangerie/farine      1321.68
# 18                    /produits-laitiers-oeufs/yogourt      414.408
# 19                           /mueesli-cereales/mueesli      1796.77
# 20                                    /chocolat/divers      1450.65
# 21             /boulangerie/ingredients-de-boulangerie      1616.82
# 22   /garnitures-ingredients/legumes-legumes-au-vin...      194.379
# 23                /boissons-chaudes-froides/sirop-soda      166.765
# 24                               /chocolat/specialites      1745.79
# 25                     /poisson-fruits-de-mer/traiteur      665.763
# 26            /produits-surgeles/poisson-fruits-de-mer      595.657
# 27          /boissons-chaudes-froides/boissons-sucrees      134.985
# 28   /boissons-chaudes-froides/jus-de-fruits-de-leg...      173.893
# 29            /garnitures-ingredients/legumes-a-salade      275.704
# ..                                                 ...          ...
# 73                       /boissons-chaudes-froides/the        178.5
# 74                      /produits-laitiers-oeufs/oeufs          650
# 75                                   /viande/saucisses      1191.04
# 76                   /boulangerie/produits-sans-gluten       1076.5
# 77                           /fruits-et-legumes/fruits         1296
# 78                        /viande/viande-sechee-jambon      1005.17
# 79                                    /viande/volaille      735.833
# 80   /garnitures-ingredients/legumineuses-haricots-...      1301.43
# 81   /garnitures-ingredients/legumineuses-farce-pou...      512.333
# 82                                      /viande/gibier          482
# 83                     /produits-laitiers-oeufs/beurre      2777.74
# 84   /boulangerie/produits-frais-de-boulangerie-non...      1220.73
# 85              /boulangerie/pains-longue-conservation         1487
# 86   /boissons-chaudes-froides/boissons-faibles-en-...       1523.2
# 87          /boulangerie/pains-bio-longue-conservation      950.857
# 88                                /petit-dejeuner/miel       1416.5
# 89                         /plats-cuisines/convenience          698
# 90                  /produits-laitiers-oeufs/margarine         2328
# 91                      /garnitures-ingredients/divers        961.5
# 92        /boissons-chaudes-froides/boissons-daperitif       163.45
# 93                     /produits-laitiers-oeufs/divers          338
# 94                    /petit-dejeuner/pates-a-tartiner      1861.92
# 95                          /fruits-et-legumes/legumes      278.077
# 96              /boissons-chaudes-froides/eau-minerale            0
# 97               /garnitures-ingredients/epices-herbes        803.2
# 98           /produits-surgeles/boulangerie-patisserie       1338.5
# 99                                         /viande/bio          800
# 100                            /viande/accompagnements          354
# 101                   /boulangerie/farines-sans-gluten         1507
# 102                /chocolat/biscuits-pour-allergiques         2091
#
#          Sel (g) Protéines (g) Sucres (g) Glucides (g) Matières grasses (g)  \
# 0       0.108552       1.58572    31.8755      77.1228              1.42966
# 1         0.3205         8.335       55.5         64.7                4.995
# 2       0.097931       6.05517     5.6931          6.9             0.731034
# 3       0.173249       6.42809    46.8444      51.4036              33.7242
# 4       0.554615       8.47692    25.7808      55.8192              22.9385
# 5       0.235714       2.98571    10.2286      10.6286             0.678571
# 6        3.23159       5.78774    8.03579      30.2745              8.92297
# 7       0.363431       6.65392    32.3382      60.9118              24.6314
# 8        1.53741       2.58771    3.51058      9.17099              11.2922
# 9        1.05464       5.94643    2.33929      16.8214                  6.5
# 10       1.01013       5.55729    3.94171      15.8616               8.4253
# 11      0.117462       3.07692    23.7831      27.7608              9.30385
# 12         0.254        7.9275     36.795       55.975                16.28
# 13       1.15377       9.57736     9.5434      63.8151              10.4528
# 14       1.32586       16.8453    1.60387      2.43315              22.7878
# 15      0.489859       6.53732    14.4761      31.5824              17.7761
# 16      0.355301       12.1313    13.2277      57.1952              11.9494
# 17      0.224211       12.8684    1.15263         66.3              2.47895
# 18     0.0981633       3.52449    12.0622      12.7255              3.63163
# 19      0.327692          12.5    14.8269      52.8846              15.0769
# 20        0.3245         5.065     52.665        74.24                 2.48
# 21      0.327536       6.17295    30.9275        48.27              17.1889
# 22       1.63106       1.70606    3.16727      6.25152              1.21667
# 23   0.000882353     0.0441176    9.67647      9.67647            0.0441176
# 24          0.41       6.33448    37.5483      67.6724              14.4517
# 25       2.26263       16.6158    1.58421      3.67632              8.91842
# 26       1.10786       13.7644   0.872857      6.54243              7.00286
# 27    0.00508475     0.0830508    6.29153      6.77627              0.40678
# 28     0.0472816      0.448544    8.72524      9.26408             0.325437
# 29      0.601852       3.62222    2.02593      9.77037              0.82963
# ..           ...           ...        ...          ...                  ...
# 73         -0.22           0.3       6.56         9.59                 -0.3
# 74        0.2475            13        0.5            1                   11
# 75         2.244         16.04       0.82         0.96                22.32
# 76          1.35          3.75       1.85           45                  5.5
# 77             0         12.75        4.5            9                 24.5
# 78       3.80345       30.1103    0.92069      1.37931               12.969
# 79       1.63333            11   0.916667      14.1667              11.6667
# 80      0.122857            23    4.07143      41.5714                  1.5
# 81       1.00167          5.25    1.25833      7.83333                 7.25
# 82         1.046           7.9       8.24         14.4                  2.3
# 83     0.0736842      0.526316   0.368421     0.557895              77.4737
# 84       1.36364       8.90909    3.80909      46.1818              7.01818
# 85           1.4       9.11429    1.57143      36.1429              18.1286
# 86         1.474          34.2       24.1         38.7                 6.04
# 87       1.27286       6.08571        3.1      39.9571              2.74286
# 88      0.040625           0.5         82           82               0.4375
# 89          1.38          19.2          1          1.9                  9.2
# 90          0.24           0.2       4.36         7.05                   56
# 91           2.7         3.725        8.2         9.95               19.275
# 92        0.0695        0.2205      8.835         9.11                 0.16
# 93         0.088           8.1          9          9.6                 0.98
# 94      0.243846       5.52308    45.6462      54.5846              26.6462
# 95      0.192308       1.90769   0.615385      12.8692             0.476923
# 96          0.17             0          0            0                    0
# 97       32.3333       7.10667    3.56667      18.4067                 9.68
# 98      0.528333           4.5         12         33.5              17.8333
# 99           1.2            18        0.5            1                   13
# 100         0.03           0.5         17           19                  0.5
# 101          1.3             6          4           68                    5
# 102        0.025           6.4         38           51                   29
#
#     Acides gras saturés (g) Fibres alimentaires (g) Biotine (µg)  \
# 0                      0.18                 2.92138     0.344828
# 1                     0.235                    6.65         1.25
# 2                  0.468966                 1.72414     0.241379
# 3                   3.20614                 2.91827    0.0722022
# 4                   2.65769                     4.8            0
# 5                         0                 1.75714            0
# 6                  0.417949                 2.43641            0
# 7                   2.36275                 2.71373            0
# 8                  0.156655                0.995563            0
# 9                  0.267857                 1.87143            0
# 10                0.0962312                 2.02915            0
# 11                 0.153846                 1.47231            0
# 12                    0.965                    5.77            0
# 13                 0.767925                 6.32075            0
# 14                 0.585083                0.134254            0
# 15                 0.654225                 3.08592            0
# 16                 0.656627                 10.3831     0.963855
# 17                0.0263158                 5.07895            0
# 18                 0.168367                0.579592            0
# 19                 0.519231                     9.5            0
# 20                        0                  0.6175         1.25
# 21                 0.414493                 4.51691            0
# 22                 0.030303                 2.15712            0
# 23                        0                0.138235            0
# 24                  2.22069                 1.90345            0
# 25                0.0131579                0.710526            0
# 26               0.00714286                0.541429            0
# 27               -0.0169492               0.0423729            0
# 28               -0.0145631                0.343689      0.23301
# 29                        0                 3.38519            0
# ..                      ...                     ...          ...
# 73                     -0.1                    -0.3            0
# 74                        0                       0            0
# 75                     0.92                    0.46            0
# 76                     0.25                     5.5            0
# 77                        0                       1            0
# 78                 0.586207                0.465517            0
# 79                        0                 1.26667            0
# 80                0.0714286                 17.1429            0
# 81                0.0416667                 2.68333            0
# 82                     0.16                    2.14            0
# 83                        0                       0            0
# 84                0.0454545                 2.90909            0
# 85                        2                     5.8            0
# 86                      0.1                     7.4           45
# 87                        0                 8.35714            0
# 88                        0                       0            0
# 89                        0                     0.5            0
# 90                      4.4                    0.35            0
# 91                        0                    1.75            0
# 92                     0.03                   0.025            0
# 93                     0.02                     0.4            0
# 94                        0                 1.05385            0
# 95                        0                 1.84615            0
# 96                        0                       0            0
# 97                        0                    0.78            0
# 98                        0                 1.91667            0
# 99                        0                       0            0
# 100                       0                     0.5            0
# 101                       0                       8            0
# 102                     7.3                     4.5            0
#
#                  ...               Vitamine E (Tocopherol) (mg)  \
# 0                ...                                  0.0827586
# 1                ...                                      1.896
# 2                ...                                   0.682759
# 3                ...                                  0.0353791
# 4                ...                                          0
# 5                ...                                          0
# 6                ...                                          0
# 7                ...                                          0
# 8                ...                                          0
# 9                ...                                          0
# 10               ...                                          0
# 11               ...                                          0
# 12               ...                                     0.2475
# 13               ...                                          0
# 14               ...                                          0
# 15               ...                                          0
# 16               ...                                          0
# 17               ...                                          0
# 18               ...                                          0
# 19               ...                                   0.461538
# 20               ...                                        0.3
# 21               ...                                          0
# 22               ...                                          0
# 23               ...                                          0
# 24               ...                                          0
# 25               ...                                          0
# 26               ...                                          0
# 27               ...                                          0
# 28               ...                                   0.151456
# 29               ...                                          0
# ..               ...                                        ...
# 73               ...                                          0
# 74               ...                                          0
# 75               ...                                          0
# 76               ...                                          0
# 77               ...                                          0
# 78               ...                                          0
# 79               ...                                          0
# 80               ...                                          0
# 81               ...                                          0
# 82               ...                                          0
# 83               ...                                   0.263158
# 84               ...                                          0
# 85               ...                                          0
# 86               ...                                       7.66
# 87               ...                                          0
# 88               ...                                          0
# 89               ...                                          0
# 90               ...                                       4.32
# 91               ...                                          0
# 92               ...                                          0
# 93               ...                                          0
# 94               ...                                          0
# 95               ...                                          0
# 96               ...                                          0
# 97               ...                                          0
# 98               ...                                          0
# 99               ...                                          0
# 100              ...                                          0
# 101              ...                                          0
# 102              ...                                          0
#
#     Acide folique (µg) Vitamine A (µg) Vitamine D (Cholacalciferol) (µg)  \
# 0                    0               0                                 0
# 1                   95           126.4                              0.79
# 2              16.2069         34.4828                          0.313793
# 3              1.73285         2.31047                         0.0144404
# 4                    0               0                                 0
# 5                    0               0                                 0
# 6             0.666667               0                                 0
# 7                    0               0                                 0
# 8                    0               0                                 0
# 9                    0               0                                 0
# 10                   0               0                                 0
# 11                   0               0                                 0
# 12                12.4            16.5                             0.105
# 13             2.26415               0                                 0
# 14                   0         3.09392                                 0
# 15                   0               0                                 0
# 16             17.5542               0                         0.0843373
# 17                   0               0                                 0
# 18                   0               0                                 0
# 19             7.69231               0                          0.192308
# 20                   5               0                                 0
# 21                   0               0                                 0
# 22                   0               0                                 0
# 23                   0               0                                 0
# 24                   0               0                                 0
# 25                   0               0                                 0
# 26                   0               0                                 0
# 27                   0               0                                 0
# 28              1.8932         4.81942                                 0
# 29                   0               0                                 0
# ..                 ...             ...                               ...
# 73                   0               0                                 0
# 74                   0               0                                 0
# 75                   0               0                                 0
# 76                   0               0                                 0
# 77                   0               0                                 0
# 78                   0               0                                 0
# 79                   0               0                                 0
# 80                   0               0                                 0
# 81                   0               0                                 0
# 82                   0               0                                 0
# 83                   0         126.263                          0.263158
# 84                   0               0                                 0
# 85                   0               0                                 0
# 86                 133             378                              1.96
# 87             13.5714               0                                 0
# 88                   0               0                                 0
# 89                   0               0                                 0
# 90                   0             120                               0.9
# 91                   0               0                                 0
# 92                   2               0                                 0
# 93                   0               0                                 0
# 94                   0               0                                 0
# 95                   0               0                                 0
# 96                   0               0                                 0
# 97                   0               0                                 0
# 98                   0               0                                 0
# 99                   0               0                                 0
# 100                  0               0                                 0
# 101                  0               0                                 0
# 102                  0               0                                 0
#
#     Vitamine C (Acide ascorbique) (mg) Vitamine B6 (Pyridoxine) (mg)  \
# 0                              23.2345                    0.00965517
# 1                                12.64                         0.221
# 2                              4.17241                      0.865517
# 3                             0.231047                    0.00404332
# 4                                    0                             0
# 5                                    0                             0
# 6                             0.447179                     0.0151795
# 7                                    0                             0
# 8                                    0                             0
# 9                                    0                             0
# 10                            0.306533                             0
# 11                                   0                             0
# 12                                 2.8                         0.017
# 13                                   0                     0.0188679
# 14                                   0                             0
# 15                                   0                             0
# 16                                   0                      0.136386
# 17                                   0                             0
# 18                                   0                             0
# 19                             3.07692                             0
# 20                                   0                         0.035
# 21                                   0                             0
# 22                                   0                             0
# 23                            0.705882                             0
# 24                                   0                             0
# 25                                   0                             0
# 26                                   0                             0
# 27                            0.813559                             0
# 28                             3.87379                     0.0131068
# 29                                   0                             0
# ..                                 ...                           ...
# 73                                -0.2                             0
# 74                                   0                             0
# 75                                   0                             0
# 76                                   0                             0
# 77                                  15                             0
# 78                                   0                             0
# 79                                   0                             0
# 80                                   0                             0
# 81                                   0                             0
# 82                                   0                             0
# 83                                   0                             0
# 84                                   0                             0
# 85                                   0                             0
# 86                                40.1                          1.29
# 87                                   0                             0
# 88                                   0                             0
# 89                                   0                             0
# 90                                   0                            42
# 91                                   0                             0
# 92                                   0                             0
# 93                                   0                             0
# 94                                   0                             0
# 95                                   0                             0
# 96                                   0                             0
# 97                                   0                             0
# 98                                   0                             0
# 99                                   0                             0
# 100                                  0                             0
# 101                                  0                             0
# 102                                  0                             0
#
#     Vitamine B5 (acide pantothénique) (mg) Vitamine B3 (Niacine) (mg)  \
# 0                                0.0413793                   0.110345
# 1                                     0.65                       2.53
# 2                                 0.882759                    3.86207
# 3                               0.00866426                  0.0462094
# 4                                        0                          0
# 5                                        0                          0
# 6                                0.0261538                  0.0784615
# 7                                        0                          0
# 8                                        0                          0
# 9                                        0                          0
# 10                                       0                          0
# 11                                       0                          0
# 12                                   0.124                     0.1975
# 13                                       0                   0.192453
# 14                                       0                          0
# 15                                       0                          0
# 16                                0.314458                    1.39277
# 17                                       0                          0
# 18                                       0                          0
# 19                                0.230769                          0
# 20                                    0.15                        0.4
# 21                                       0                          0
# 22                                       0                          0
# 23                                       0                          0
# 24                                       0                          0
# 25                                       0                          0
# 26                                       0                          0
# 27                                       0                          0
# 28                               0.0359223                   0.119417
# 29                                       0                          0
# ..                                     ...                        ...
# 73                                       0                          0
# 74                                       0                          0
# 75                                       0                          0
# 76                                       0                          0
# 77                                       0                          0
# 78                                       0                          0
# 79                                       0                          0
# 80                                       0                          0
# 81                                       0                          0
# 82                                       0                          0
# 83                                       0                          0
# 84                                       0                          0
# 85                                       0                          0
# 86                                    2.68                       13.4
# 87                                       0                          0
# 88                                       0                          0
# 89                                       0                          0
# 90                                       0                          0
# 91                                       0                          0
# 92                                       0                          0
# 93                                       0                          0
# 94                                       0                          0
# 95                                       0                          0
# 96                                       0                          0
# 97                                       0                          0
# 98                                       0                          0
# 99                                       0                          0
# 100                                      0                          0
# 101                                      0                          0
# 102                                      0                          0
#
#     Vitamine B2 (Riboflavine) (mg) Vitamine B12 (Cobalamine) (µg)
# 0                       0.00965517                      0.0172414
# 1                            0.256                         0.3955
# 2                        0.0655172                       0.806897
# 3                       0.00404332                     0.00722022
# 4                                0                              0
# 5                                0                              0
# 6                       0.00717949                     0.00769231
# 7                                0                              0
# 8                                0                              0
# 9                                0                              0
# 10                               0                              0
# 11                               0                              0
# 12                           0.017                          0.051
# 13                       0.0169811                              0
# 14                       0.0038674                              0
# 15                               0                              0
# 16                        0.157831                       0.248193
# 17                               0                              0
# 18                               0                              0
# 19                       0.0538462                      0.0961538
# 20                               0                         0.0625
# 21                               0                              0
# 22                               0                              0
# 23                               0                              0
# 24                               0                              0
# 25                               0                              0
# 26                               0                              0
# 27                               0                              0
# 28                      0.00970874                      0.0247573
# 29                               0                              0
# ..                             ...                            ...
# 73                               0                              0
# 74                               0                              0
# 75                               0                              0
# 76                               0                              0
# 77                               0                              0
# 78                               0                              0
# 79                               0                              0
# 80                               0                              0
# 81                               0                              0
# 82                               0                              0
# 83                               0                              0
# 84                               0                              0
# 85                               0                              0
# 86                             1.3                           1.52
# 87                               0                              0
# 88                               0                              0
# 89                               0                              0
# 90                               0                           0.15
# 91                               0                              0
# 92                               0                          0.013
# 93                               0                              0
# 94                               0                              0
# 95                               0                              0
# 96                               0                              0
# 97                               0                              0
# 98                               0                              0
# 99                               0                              0
# 100                              0                              0
# 101                              0                              0
# 102                              0                              0
#
# [103 rows x 21 columns]

# %% [markdown]
# ### /!\ Think of modifying the treatment of getParsedNutrients in master
