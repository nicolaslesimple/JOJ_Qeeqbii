# %%
import pandas as pd
import numpy as np
import sys

# %% [markdown]
# ### Reading of the train set

# %%
column_names = ['id','name','barcode','category','Énergie (kJ)','Sel (g)','Protéines (g)','Sucres (g)',\
                'Glucides (g)','Matières grasses (g)','Acides gras saturés (g)','Fibres alimentaires (g)',\
                'Biotine (µg)','Vitamine B1 (Thiamine) (mg)','Vitamine E (Tocopherol) (mg)','Acide folique (µg)',\
                'Vitamine A (µg)','Vitamine D (Cholacalciferol) (µg)','Vitamine C (Acide ascorbique) (mg)',\
                'Vitamine B6 (Pyridoxine) (mg)','Vitamine B5 (acide pantothénique) (mg)','Vitamine B3 (Niacine) (mg)',\
                'Vitamine B2 (Riboflavine) (mg)','Vitamine B12 (Cobalamine) (µg)','endline', 'extra']
train_set = pd.read_csv('../clustering/raw_cluster_train_set.csv', names = column_names)

# %% [markdown]
# ### Dropping unfound products in OpenFood

# %%
# dropping first line that repeats columns
train_set.drop(0, inplace=True)
train_set = train_set[train_set['name'].notnull()]

# %% [markdown]
# ### Processing of product names containing ','
#
# For the elements of the train set that had a ',' in their name the csv formatting shifted every value and created an extra column. Every value is reassigned to its right place below.

# %%
elem_to_shift = train_set[train_set['extra'].notnull()].copy()
for i in range(elem_to_shift.shape[0]):
    line = elem_to_shift.iloc[i].copy()
    line_values = line.values
    line_values[1] = line_values[1] + line_values[2]
    line_values = np.delete(line_values, 2)
    line_values = np.append(line_values, [np.nan])
    elem_to_shift.iloc[i] = line_values

train_set[train_set['extra'].notnull()] = elem_to_shift

# %% [markdown]
# ### Processing categories that have more than 2 levels by removing extra levels

# %%
catagory_column_value = train_set['category'].values

for i in range(train_set.shape[0]):
    if catagory_column_value[i].count('/') > 2:
        current_category =  catagory_column_value[i]
        slash_indexes = [pos for pos, char in enumerate(current_category) if char == '/']
        catagory_column_value[i] = current_category[:slash_indexes[2]]

train_set['category'] = catagory_column_value

# %% [markdown]
# ### Dropping useless columns

# %%
train_set.drop(['extra', 'endline'], axis = 1, inplace = True)

# %%
train_set.columns
# Out:
# Index(['id', 'name', 'barcode', 'category', 'Énergie (kJ)', 'Sel (g)',
#        'Protéines (g)', 'Sucres (g)', 'Glucides (g)', 'Matières grasses (g)',
#        'Acides gras saturés (g)', 'Fibres alimentaires (g)', 'Biotine (µg)',
#        'Vitamine B1 (Thiamine) (mg)', 'Vitamine E (Tocopherol) (mg)',
#        'Acide folique (µg)', 'Vitamine A (µg)',
#        'Vitamine D (Cholacalciferol) (µg)',
#        'Vitamine C (Acide ascorbique) (mg)', 'Vitamine B6 (Pyridoxine) (mg)',
#        'Vitamine B5 (acide pantothénique) (mg)', 'Vitamine B3 (Niacine) (mg)',
#        'Vitamine B2 (Riboflavine) (mg)', 'Vitamine B12 (Cobalamine) (µg)'],
#       dtype='object')

# %% [markdown]
# ### Dropping products that didn't have a nutrient list and dropping those that have a -1 as nutrient

# %%
train_set_values = train_set[train_set.columns[4:]].values.astype(float)
train_set = train_set[np.abs(np.sum(train_set_values, axis =1)) > 1e-3]

# %%
indexes_to_drop = []
# update train_set indexes so that it ranges from 0 to train_set.shape[0]-1

train_set.index = range(train_set.shape[0])
train_set_values = train_set[train_set.columns[4:]].values.astype(float)

for i in range(train_set.shape[0]):
    if -1 in train_set_values[i]:
        indexes_to_drop += [i]
print(indexes_to_drop)

train_set = train_set.drop(indexes_to_drop)
# Out:
# [10, 45, 55, 74, 78, 270, 340, 465, 593, 817, 917, 929, 1300, 1480, 1733, 1754, 1757, 1783, 1819, 2045, 2183, 2207, 2617, 2896, 2937, 2938, 3213, 3261, 3269, 3456, 3496, 3657, 3671, 3940, 3969, 4005, 4194, 4339, 4560, 4565]

# %%
train_set
# Out:
#          id                                               name        barcode  \
# 0         0                                 V6 White Spearmint  5700626503125
# 1         2                           M-Quick Boisson au cacao  7613312049297
# 2         6                                Skai (Crunchy mint)  7616500651555
# 3         8                             RedBull : Energy Drink  9002490206789
# 4        10  Frey Milch Extra Chocolat au lait extra fin sa...  7616500912472
# 5        13   MIGROS BIO Choco Cookies aux pépites de chocolat  7617400037784
# 6        15                       LONGOBARDI : Pomodori pelati  8002510010007
# 7        23                                      Kinder Riegel  4008400221021
# 8        25  Namaste India PALAK PANEER Epinards et fromage...  7613312065945
# 9        29                                 MINDOR petit berre  7617400032796
# 11       42            M Classic Délices au poulet et au curry  7613269184584
# 12       49                  Storico pastifico Garofalo trofie  8000139929113
# 13       53  Mary Jane's American style ice cream caramel s...  7617400049619
# 14       55                         Frey Blanca Chocolat Blanc  7616500650961
# 15       58                               Smams Sugarfree Mint  7613269347477
# 16       61  Frey – Milch-Nuss – Chocolat au lait avec nois...  7616500010031
# 17       65                   Farmer Soft Myrtille \u0026 Mûre  7613269187516
# 18       75                              Couscous avec Légumes  7613312137116
# 19       77                        Butterli BISCUITS AU BEURRE  7617400030044
# 20       86                             ORIGINAL Zwieback Mini  7617400036596
# 21       88                      M-Budget Fromage à pâte molle  7610200401366
# 22       92                                 Petit pain de Sils  7613312087053
# 23       94                              YOU LOW CARB CRUNCHY   7613312147115
# 24       98            ALTANATURA Dinkel Vollkorn Mehl Bioland  4104420140684
# 25      104         M Classic Pikant Sauce š Salade Sans Huile  7613269181644
# 26      111                           Bifidus joghurt Myrtille  7616600711197
# 27      113                               Farmer Croc Chocolat  7610200085047
# 28      115               M Classic Petits pains croustillants  7613269370314
# 29      117                                 Yupi Pfirsichringe  4003084010312
# 30      124                          Alnatura Coulis de mangue  4104420021167
# ...     ...                                                ...            ...
# 4624  22539                                 Mokka Crème Glacée  7617400043396
# 4625  22542                                     Grains de maïs  7610200012081
# 4626  22548                   Frey Classic Branches Cornflakes  7616500652057
# 4627  22552       Happy Hour Gruyère-Laugengipfeli mit Gruyère  7613312066638
# 4628  22554                            Migros Bio Huile de lin  7613269354703
# 4629  22557  Glace à l'arôme de vanille- de fraise et de ch...  7617400046731
# 4630  22562                      M-Classic Gelée (déshydratée)  7613269181682
# 25     /garnitures-ingredients/soupes-sauces-bouillon         50.0     4.3
# 26                   /produits-laitiers-oeufs/yogourt        410.0     0.1
# 27                          /mueesli-cereales/mueesli       1921.0    0.58
# 28           /boulangerie/biscottes-pain-croustillant       1656.0     1.7
# 29                                   /chocolat/divers       1404.0     0.2
# 30            /boulangerie/ingredients-de-boulangerie        472.0     0.1
# ...                                               ...          ...     ...
# 4624               /produits-surgeles/glace-entremets       1140.0    0.12
# 4625         /garnitures-ingredients/legumes-a-salade        510.0     0.5
# 4626                               /chocolat/chocolat       2190.0     0.2
# 4627              /produits-surgeles/aperitif-dessert       8400.0     0.0
# 4628   /garnitures-ingredients/ingredients-de-cuisson       3441.0     0.0
# 4629               /produits-surgeles/glace-entremets        614.0    0.27
# 4630            /garnitures-ingredients/epices-herbes         60.0     1.2
# 4631                /produits-laitiers-oeufs/fromages       1460.0     1.6
# 4632   /garnitures-ingredients/soupes-sauces-bouillon        100.0    0.87
# 4633                     /aperitif/biscuits-aperitifs       1977.0     2.5
# 4634                /produits-laitiers-oeufs/fromages       1015.0     0.0
# 4635           /garnitures-ingredients/garnitures-bio       1498.0    0.02
# 4636   /garnitures-ingredients/soupes-sauces-bouillon        490.0     1.0
# 4637              /boulangerie/boulangerie-patisserie       1630.0     0.2
# 4638                            /chocolat/specialites       1684.0    0.21
# 4639                       /chocolat/biscuits-gaufres       2241.0    0.55
# 4640         /produits-surgeles/poisson-fruits-de-mer        343.0     0.2
# 4641                          /aperitif/noix-grillees       2151.0     2.8
# 4642                 /produits-laitiers-oeufs/yogourt        403.0    0.08
# 4643                  /poisson-fruits-de-mer/traiteur        825.0     3.0
# 4644     /boissons-chaudes-froides/boissons-daperitif        148.0     0.0
# 4645              /chocolat/jours-de-fetes-evenements       1884.0    0.03
# 4646                 /produits-laitiers-oeufs/yogourt        406.0    0.13
# 4647                   /produits-laitiers-oeufs/creme       1400.0     0.1
# 4648                    /chocolat/bonbons-chewing-gum       1372.0    0.02
# 4649                               /chocolat/chocolat       2240.0    0.14
# 4650              /boissons-chaudes-froides/the-glace          7.0    0.01
# 4651   /produits-laitiers-oeufs/lait-boissons-lactees        178.0    0.13
# 4652       /garnitures-ingredients/fruits-en-conserve        320.0     0.0
# 4653                      /garnitures-ingredients/riz       1450.0    0.03
#
#      Protéines (g) Sucres (g) Glucides (g) Matières grasses (g)  \
# 0              0.4        0.0         67.0                  0.6
# 1              5.0       80.0         82.0                  3.0
# 2              0.2        0.1         64.0                  0.0
# 3              0.0       11.0         11.0                  0.0
# 4              8.0       11.0         51.0                 35.0
# 5              7.0       27.0         61.0                 26.0
# 6              1.5        4.5          4.5                  0.5
# 7              8.7       53.3         53.5                 35.0
# 8              4.0        2.5          5.0                  7.0
# 9              6.0       34.0         64.0                 25.0
# 11             5.0        2.0         19.0                  7.0
# 12            12.0        2.0         61.0                  1.0
# 13             3.0       31.0         33.0                 14.0
# 14             6.0       52.0         52.0                 40.0
catagory_column_value = train_set['category'].values

for i in range(train_set.shape[0]):
    if catagory_column_value[i].count('/') < 2:
        catagory_column_value[i] = "TO_CLASSIFY"

train_set['category'] = catagory_column_value

# %% [markdown]
# ### Saving preprocessed train set before computing clusters

# %%
train_set.shape
# Out:
# (4614, 24)

# %%
path = '../clustering/preprocessed_cluster_train_set.csv'
train_set.to_csv(path, index = False)

# %% [markdown]
# ### Rereading of the train_set

# %%
train_set = pd.read_csv(path)

# %% [markdown]
# ### Dropping columns not useful for clustering

# %%
train_set.drop(['id', 'name', 'barcode'], axis = 1, inplace = True)

# %% [markdown]
# ### Computing cluster centers

# %%
unique_categories = train_set['category'].unique()
cluster_centers = np.zeros((unique_categories.shape[0], train_set.shape[1]-1))

# We compute the nutrient center of gravity of each of the 250 categories
for index, category in enumerate(unique_categories):
    category_train_set = train_set[train_set['category'] == category]
    category_train_set_values = category_train_set.values[:,1:].astype(float)
    nutrient_stack = np.zeros(train_set.shape[1]-1)
    
    for i in range(category_train_set_values.shape[0]):
        
        nutrient_array = category_train_set_values[i,:]
        nutrient_stack = nutrient_stack + nutrient_array
    
    
    cluster_centers[index] = nutrient_stack / category_train_set_values.shape[0]

unique_categories = np.expand_dims(unique_categories, axis = 1)
cluster_centers_values = np.concatenate([unique_categories, cluster_centers], axis = 1)
    
cluster_centers_df = pd.DataFrame(cluster_centers_values, columns = column_names[3:-2])

# %% [markdown]
# ### Change cluster type names to match with enum types

# %%
cluster_centers_categories_values = cluster_centers_df['category'].values.copy()

for i in range(cluster_centers_categories_values.shape[0]):
    category_name = cluster_centers_categories_values[i]
    category_name = category_name.replace('-', '_')
    category_name = category_name.upper()
    cluster_centers_categories_values[i] = category_name

cluster_centers_df['category'] = cluster_centers_categories_values

# %% [markdown]
# ### We drop the "TO CLASSIFY" category from the cluster centers df

# %%
cluster_centers_df = cluster_centers_df[cluster_centers_df['category'] != 'TO_CLASSIFY']

# %% [markdown]
# ### Saving non-normalized data

# %%
cluster_centers_df.to_csv('../clustering/non_normalized_cluster_nutrient_centers.csv')

# %% [markdown]
# ### Normalize the data

# %%
cluster_centers_df[cluster_centers_df.columns[1:]]
# Out:
#     Énergie (kJ)      Sel (g) Protéines (g) Sucres (g) Glucides (g)  \
# 0        1168.26     0.108552       1.58572    31.8755      77.1228
# 1        1480.65       0.3205         8.335       55.5         64.7
# 2        264.792     0.159167       5.29583    6.37083      6.79583
# 3        2250.61     0.173249       6.42809    46.8444      51.4036
# 4        1936.35     0.554615       8.47692    25.7808      55.8192
# 5        253.429     0.235714       2.98571    10.2286      10.6286
# 6        983.022       3.2534       5.82273    8.08237      30.4357
# 7        2066.71     0.363431       6.65392    32.3382      60.9118
# 8        642.679      1.05464       5.94643    2.33929      16.8214
# 9        680.106      1.01013       5.55729    3.94171      15.8616
# 10       889.729     0.126124        3.0969    23.8202      27.8054
# 11       1670.03        0.254        7.9275     36.795       55.975
# 12       1763.28      1.15377       9.57736     9.5434      63.8151
# 12               10.4528                0.767925                 6.32075
# 13               22.9486                 0.59162                0.141341
# 15               11.9494                0.656627                 10.3831
# 16               2.47895               0.0263158                 5.07895
# 17               11.3913                0.158824                 1.01107
# 18               3.63163                0.168367                0.579592
# 19                 15.16                    0.54                    9.56
# 20                  2.48                       0                  0.6175
# 21               17.2772                0.416505                 4.54369
# 22               1.21667                0.030303                 2.15712
# 23             0.0441176                       0                0.138235
# 24               14.4517                 2.22069                 1.90345
# 25               8.91842               0.0131579                0.710526
# 26               7.11884              0.00724638                0.549275
# 27              0.431034                       0               0.0603448
# 28              0.351683               0.0049505                0.370297
# 29               0.82963                       0                 3.38519
# 30             0.0368421              0.00526316               0.0263158
# ..                   ...                     ...                     ...
# 73                    11                       0                       0
# 74                 22.32                    0.92                    0.46
# 75                   5.5                    0.25                     5.5
# 76                  24.5                       0                       1
# 77               11.9321                0.607143                0.482143
# 78               11.6667                       0                 1.26667
# 79                   1.5               0.0714286                 17.1429
# 80                  7.25               0.0416667                 2.68333
# 81                   2.3                    0.16                    2.14
# 82               77.2222                       0                       0
# 83               7.01818               0.0454545                 2.90909
# 84               18.1286                       2                     5.8
# 85                  6.04                     0.1                     7.4
# 86               2.74286                       0                 8.35714
# 87                0.4375                       0                       0
# 88                   9.2                       0                     0.5
# 89                     0                       0                       0
# 90                    56                     4.4                    0.35
# 91                19.275                       0                    1.75
# 92                  0.16                    0.03                   0.025
# 93                  0.98                    0.02                     0.4
# 94               26.6462                       0                 1.05385
# 95              0.476923                       0                 1.84615
# 96                     0                       0                       0
# 97                  9.68                       0                    0.78
# 98               17.8333                       0                 1.91667
# 99                    13                       0                       0
# 100                  0.5                       0                     0.5
# 101                    5                       0                       8
# 102                   29                     7.3                     4.5
#
#     Biotine (µg) Vitamine B1 (Thiamine) (mg) Vitamine E (Tocopherol) (mg)  \
# 0       0.344828                  0.00758621                    0.0827586
# 1           1.25                      0.1735                        1.896
# 2       0.333333                   0.0583333                        0.575
# 3      0.0722022                   0.0031769                    0.0353791
# 4              0                           0                            0
# 5              0                           0                            0
# 6              0                  0.00618557                            0
# 7              0                           0                            0
# 8              0                           0                            0
# 9              0                           0                            0
# 10             0                           0                            0
# 11             0                      0.0225                       0.2475
# 12             0                   0.0132075                            0
# 13             0                           0                            0
# 15      0.963855                    0.113373                            0
# 16             0                           0                            0
# 17             0                           0                            0
# 18             0                           0                            0
# 19             0                       0.112                         0.48
# 20          1.25                           0                          0.3
# 21             0                           0                            0
# 22             0                           0                            0
# 23             0                           0                            0
# 24             0                           0                            0
# 25             0                           0                            0
# 26             0                           0                            0
# 27             0                           0                            0
# 28      0.237624                   0.0158416                     0.154455
# 29             0                           0                            0
# 30             0                           0                            0
# ..           ...                         ...                          ...
# 73             0                           0                            0
# 74             0                           0                            0
# 75             0                           0                            0
# 76             0                           0                            0
# 77             0                           0                            0
# 78             0                           0                            0
# 79             0                           0                            0
# 80             0                           0                            0
# 18                               0                              0
# 19                           0.056                            0.1
# 20                               0                         0.0625
# 21                               0                              0
# 22                               0                              0
# 23                               0                              0
# 24                               0                              0
# 25                               0                              0
# 26                               0                              0
# 27                               0                              0
# 28                      0.00990099                      0.0252475
# 29                               0                              0
# 30                               0                              0
# ..                             ...                            ...
# 73                               0                              0
# 74                               0                              0
# 75                               0                              0
# 76                               0                              0
# 77                               0                              0
# 78                               0                              0
# 79                               0                              0
# 80                               0                              0
# 81                               0                              0
# 82                               0                              0
# 83                               0                              0
# 84                               0                              0
# 85                             1.3                           1.52
# 86                               0                              0
# 87                               0                              0
# 88                               0                              0
# 89                               0                              0
# 90                               0                           0.15
# 91                               0                              0
# 92                               0                          0.013
# 93                               0                              0
# 94                               0                              0
# 95                               0                              0
# 96                               0                              0
# 97                               0                              0
# 98                               0                              0
# 99                               0                              0
# 100                              0                              0
# 101                              0                              0
# 102                              0                              0
#
# [102 rows x 20 columns]

# %%
cluster_centers_values = cluster_centers_df[cluster_centers_df.columns[1:]].values.astype(np.float64)
cluster_centers_mean = np.mean(cluster_centers_values, axis = 0)
expanded_cluster_centers_mean = np.repeat(np.expand_dims(cluster_centers_mean, 0), cluster_centers_df.shape[0], axis =0)

cluster_centers_std = np.std(cluster_centers_values, axis = 0, ddof=1)
expanded_cluster_centers_std = np.repeat(np.expand_dims(cluster_centers_std, 0), cluster_centers_df.shape[0], axis =0)

normalized_cluster_centers_values = (cluster_centers_values - expanded_cluster_centers_mean) / expanded_cluster_centers_std
final_cluster_centers_values = np.c_[cluster_centers_df['category'].values, normalized_cluster_centers_values]

# %%
np.c_[np.expand_dims(np.array('std'), 0), np.expand_dims(cluster_centers_std, 0)]
# Out:
# array([['std', '656.3225781629042', '3.2417905186235414',
#         '6.756990329873574', '15.09728548259974', '24.342119677076273',
#         '13.571863856938599', '1.0141491791985042', '3.6912433746902957',
#         '4.455665777537821', '0.10529878950598048', '1.150027452192731',
#         '16.40606921395684', '42.83546968643756', '0.22922032557696864',
#         '4.956335327575863', '4.1587027099051115', '0.2886633196530765',
#         '1.417002844196999', '0.13338263347784496', '0.18760675392477022']],
#       dtype='<U32')

# %%
cluster_centers_df = pd.DataFrame(data=final_cluster_centers_values, columns=cluster_centers_df.columns)
mean_row = np.c_[np.expand_dims(np.array('MEAN'), 0), np.expand_dims(cluster_centers_mean, 0)]
cluster_centers_df = cluster_centers_df.append(pd.DataFrame(data = mean_row, columns=cluster_centers_df.columns))

std_row = np.c_[np.expand_dims(np.array('STD'), 0), np.expand_dims(cluster_centers_std, 0)]
cluster_centers_df = cluster_centers_df.append(pd.DataFrame(data = std_row, columns=cluster_centers_df.columns))

# %% [markdown]
# ### Saving normalized cluster centers

# %%
cluster_centers_df.to_csv('../clustering/cluster_nutrient_centers.csv', index=False)

# %% [markdown]
# ### /!\ Think of modifying the treatment of getParsedNutrients in master
# ### /!\ Add Acides gras monoinsaturés (g) and Acides gras poly-insaturés (g)
